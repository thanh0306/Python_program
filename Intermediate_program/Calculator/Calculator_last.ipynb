# %% [markdown]
# ## An appropriate Calculator
# Every time the user gives numbers to the program, the system asks for the numbers with the prompt "Give a number: " and continues until a valid number is given. If the number is not correct, the system gives an error message "This input is invalid."

# %%
import math 
def asknumber1():
    while True:
        try:
            
            number1 = float(input("Give a number: "))
            return number1
        except Exception:
            print("This input is invalid.")
def asknumber2():
    while True:
        try:
            number2 = float(input("Give a number: "))
            return number2
        except Exception:
            print("This input is invalid.")
def askselect():
    while True:
        try:
            select = int(input("Please select something (1-8): "))
            return select
        except Exception:
            print("This input is invalid.")            
            
def main():
    result = 0
    select = 0
    print("Calculator")
    x = asknumber1()
    y = asknumber2()
    s = 0
    while s != 8:
       
        print("(1) +\n(2) -\n(3) *\n(4) /\n(5) sin(number1/number2)\n(6) cos(number1/number2)\n(7) Change numbers\n(8) Quit")
        print("Current numbers: {} {}".format(x, y))
        s = askselect()
        if s == 1:
            result = x + y
            print("The result is: {}".format(result))
        elif s == 2:
            result = x - y
            print("The result is: {}".format(result))
        elif s == 3:
            result = x * y
            print("The result is: {}".format(result))
        elif s == 4:
            result = x / y
            print("The result is: {}".format(result))
        elif s == 5:
            temp = x / y
            result = math.sin(temp)
            print("The result is: {}".format(result))
        elif s == 6:
            temp = x / y
            result = math.cos(x/y)
            print("The result is: {}".format(result))
        elif s == 7:
            
            x = asknumber1()
            y = asknumber2()
            continue 
          

    print("Thank you!")

if __name__ == "__main__":
    main()
# Out:
# Calculator
# Give a number: thanh
# This input is invalid.
# Give a number: nguyen
# This input is invalid.
# Give a number: 5
# Give a number: 6
# (1) +
# (2) -
# (3) *
# (4) /
# (5) sin(number1/number2)
# (6) cos(number1/number2)
# (7) Change numbers
# (8) Quit
# Current numbers: 5.0 6.0
# Please select something (1-8): 5.
# This input is invalid.
# Please select something (1-8): 5
# The result is: 0.7401768531960371
# (1) +
# (2) -
# (3) *
# (4) /
# (5) sin(number1/number2)
# (6) cos(number1/number2)
# (7) Change numbers
# (8) Quit
# Current numbers: 5.0 6.0
# Please select something (1-8): 6
# The result is: 0.6724122440830567
# (1) +
# (2) -
# (3) *
# (4) /
# (5) sin(number1/number2)
# (6) cos(number1/number2)
# (7) Change numbers
# (8) Quit
# Current numbers: 5.0 6.0
# Please select something (1-8): 9
# (1) +
# (2) -
# (3) *
# (4) /
# (5) sin(number1/number2)
# (6) cos(number1/number2)
# (7) Change numbers
# (8) Quit
# Current numbers: 5.0 6.0
# ...
